# %%
from Absenteeism_Module import *

# %% [markdown]
# New file with same format data

# %%
model = absenteeism_model('model', 'scaler') # create an instance of the class4
# ML model and scaler to adjust the magnitude of all numbers

# %%
# Preprocess
model.load_and_clean_data('absenteeism_new_data.csv')

# %%
model.predicted_outputs() # Data at the end of pre-processing
# Out:
#     reason_group_1  reason_group_2  reason_group_3  reason_group_4  month  \
# 0            False             0.0           False            True      6
# 1             True             0.0           False           False      6
# 2            False             0.0           False            True      6
# 3            False             0.0           False            True      6
# 4             True             0.0           False           False      6
# 5             True             0.0           False           False      6
# 6             True             0.0           False           False      6
# 7            False             0.0           False            True      6
# 8            False             0.0           False            True      6
# 9             True             0.0           False           False      6
# 10           False             0.0           False            True      6
# 11           False             0.0            True           False      6
# ...

# %% [markdown]
# Model the probability column contains float values only these values represent the probability that a given individual is expected to be absent from work for more than three hours or as we call it accessible the other column called prediction is like a continuation of the probability column in it we see the value of 1 if the probability obtained was 50% or higher and 0 if it wasn't to wrap it up we can say that our goal in this lecture was to explain the necessary programming steps in reality especially if you are in the business intelligence department of a company you won't really need to understand all that during the following 4 lines of code will be more than enough for you then all you have to do is insert the name of the file containing the data about new observations and run the cell let's do that here we go our explanation on how to load and use the absenteeism module begins here in the next lecture

# %%
# export to_csv
model.predicted_outputs().to_csv('absenteeism_predictions.csv')
